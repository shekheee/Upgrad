# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
# %matplotlib inline


# Supress Warnings

import warnings
warnings.filterwarnings('ignore')

# %%
carprice=pd.read_csv('CarPrice_Assignment.csv')

# %%
carprice.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0  1       3          alfa-romero giulia        gas      std        two
# 1  2       3          alfa-romero stelvio       gas      std        two
# 2  3       1          alfa-romero Quadrifoglio  gas      std        two
# 3  4       2          audi 100 ls               gas      std        four
# 4  5       2          audi 100ls                gas      std        four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible  rwd        front          88.6       ...  130
# 1  convertible  rwd        front          88.6       ...  130
# 2  hatchback    rwd        front          94.5       ...  152
# 3  sedan        fwd        front          99.8       ...  109
# 4  sedan        4wd        front          99.4       ...  136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
carprice.shape
# Out:
# (205, 26)

# %%
carprice.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
carDictionary=pd.read_excel('Data Dictionary - carprices.xlsx')

# %%
pd.set_option('display.max_colwidth', -1)
carDictionary
# Out:
#                      Variable  \
# 0   Car_ID
# 1   Symboling
# 2   carCompany
# 3   fueltype
# 4   aspiration
# 5   doornumber
# 6   carbody
# 7   drivewheel
# 8   enginelocation
# 9   wheelbase
# 10  carlength
# 11  carwidth
# 12  carheight
# 13  curbweight
# 14  enginetype
# 15  cylindernumber
# 16  enginesize
# 17  fuelsystem
# 18  boreratio
# 19  stroke
# 20  compressionratio
# 21  horsepower
# 22  peakrpm
# 23  citympg
# 24  highwaympg
# 25  price(Dependent variable)
#
#                                                                                                                                      Desc
# 0   Unique id of each observation (Interger)
# 1   Its assigned insurance risk rating, A value of +3 indicates that the auto is risky, -3 that it is probably pretty safe.(Categorical)
# 2   Name of car company (Categorical)
# 3   Car fuel type i.e gas or diesel (Categorical)
# 4   Aspiration used in a car (Categorical)
# 5   Number of doors in a car (Categorical)
# ...

# %%
#Checking if there is any missing data in the dataset
carprice.isna().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
carprice['CarName'].unique()
# Out:
# array(['alfa-romero giulia', 'alfa-romero stelvio',
#        'alfa-romero Quadrifoglio', 'audi 100 ls', 'audi 100ls',
#        'audi fox', 'audi 5000', 'audi 4000', 'audi 5000s (diesel)',
#        'bmw 320i', 'bmw x1', 'bmw x3', 'bmw z4', 'bmw x4', 'bmw x5',
#        'chevrolet impala', 'chevrolet monte carlo', 'chevrolet vega 2300',
#        'dodge rampage', 'dodge challenger se', 'dodge d200',
#        'dodge monaco (sw)', 'dodge colt hardtop', 'dodge colt (sw)',
#        'dodge coronet custom', 'dodge dart custom',
#        'dodge coronet custom (sw)', 'honda civic', 'honda civic cvcc',
#        'honda accord cvcc', 'honda accord lx', 'honda civic 1500 gl',
#        'honda accord', 'honda civic 1300', 'honda prelude',
#        'honda civic (auto)', 'isuzu MU-X', 'isuzu D-Max ',
#        'isuzu D-Max V-Cross', 'jaguar xj', 'jaguar xf', 'jaguar xk',
#        'maxda rx3', 'maxda glc deluxe', 'mazda rx2 coupe', 'mazda rx-4',
# ...

# %%
#Creating a new variable company from CarName and doing some spelling corrections
carprice['Company']=carprice['CarName'].apply(lambda x: x.lower().split(' ')[0])
carprice['Company']=carprice['Company'].replace({'maxda':'mazda', 'toyouta': 'toyota', 'vokswagen':'volkswagen','vw':'volkswagen','porcshce':'porsche'})

# %%
#Dropping CarID and CarName fields

carprice.drop('car_ID',axis=1,inplace=True)
carprice.drop('CarName',axis=1,inplace=True)

# %%
#Convering Cylindernumber to integer

carprice['cylindernumber']=carprice['cylindernumber'].replace({'two':2,'three':3,'four':4,'five':5,'six':6,'eight':8,'twelve':12})

# %%
#UNIVARIATE ANALYSIS

# %%
#Plotting the price of the our target variable 'price'
plt.figure(figsize=(15,10))
plt.subplot(2,1,1)
sns.distplot(carprice['price'])
plt.subplot(2,1,2)
sns.boxplot(carprice['price'])

# %% [markdown]
# Price ranges around 5k-45k with Median around 10k

# %%
def display_count(ax):
    for p in ax.patches:
        width, height = p.get_width(), p.get_height()
        x, y = p.get_xy() 
        ax.annotate('{}'.format(height), (x+width/2-0.02, y + height+0.6),)

# %%
#Plotting the count for Fuel type and Fuel System
plt.figure(figsize=(20,10))

plt.subplot(1,2,1)
ax=sns.countplot(carprice['fueltype'])
display_count(ax)
plt.subplot(1,2,2)
ax1=sns.countplot(carprice['fuelsystem'])
display_count(ax1)

# %% [markdown]
# Majority of the vehicles(around 90%) have Gas as the fueltype. Also, mpfi and 2bbl engine type constitutes more than 75% of our total sample.

# %%
#Plotting the count for Fuel type and Fuel System
plt.figure(figsize=(20,10))

plt.subplot(1,2,1)
ax=sns.countplot(carprice['enginetype'])
display_count(ax)
plt.subplot(1,2,2)
ax1=sns.countplot(carprice['enginelocation'])
display_count(ax1)

# %% [markdown]
# Almost in all the cars, the enginelocation is in the front. Also, ohc(around 70%) is the most common type of engine.

# %%
#Plotting the count for Fuel type and Fuel System
plt.figure(figsize=(20,10))

plt.subplot(1,2,1)
ax=sns.countplot(carprice['fueltype'])
display_count(ax)
plt.subplot(1,2,2)
ax1=sns.countplot(carprice['fuelsystem'])
display_count(ax1)

# %%
#Identifying categorical variables

# Categorical boolean mask
categorical_feature_mask = carprice.dtypes==object

# filter categorical columns using mask and turn it into a list
categorical_cols = carprice.columns[categorical_feature_mask].tolist()
categorical_cols
# Out:
# ['fueltype',
#  'aspiration',
#  'doornumber',
#  'carbody',
#  'drivewheel',
#  'enginelocation',
#  'enginetype',
#  'fuelsystem',
#  'Company']

# %%
#Identifying Numerical variables

# Categorical boolean mask
numerical_feature_mask = (carprice.dtypes=='int64') | (carprice.dtypes=='float64')

# filter categorical columns using mask and turn it into a list
numerical_cols = carprice.columns[numerical_feature_mask].tolist()
numerical_cols
# Out:
# ['symboling',
#  'wheelbase',
#  'carlength',
#  'carwidth',
#  'carheight',
#  'curbweight',
#  'cylindernumber',
#  'enginesize',
#  'boreratio',
#  'stroke',
#  'compressionratio',
#  'horsepower',
#  'peakrpm',
#  'citympg',
#  'highwaympg',
#  'price']

# %%
#Checking number of unique values in Categorical variable
carprice[categorical_cols].nunique()
# Out:
# fueltype          2
# aspiration        2
# doornumber        2
# carbody           5
# drivewheel        3
# enginelocation    2
# enginetype        7
# fuelsystem        8
# Company           22
# dtype: int64

# %%
#Creating dummy variables for categories with 2 unique values
varlist=['fueltype','aspiration','doornumber','enginelocation','drivewheel']
pd.get_dummies(carprice,columns=varlist,prefix_sep='_',drop_first=True)
# Out:
#      symboling      carbody  wheelbase  carlength  carwidth  carheight  \
# 0    3          convertible  88.6       168.8      64.1      48.8
# 1    3          convertible  88.6       168.8      64.1      48.8
# 2    1          hatchback    94.5       171.2      65.5      52.4
# 3    2          sedan        99.8       176.6      66.2      54.3
# 4    2          sedan        99.4       176.6      66.4      54.3
# ..  ..            ...         ...         ...       ...       ...
# 200 -1          sedan        109.1      188.8      68.9      55.5
# 201 -1          sedan        109.1      188.8      68.8      55.5
# 202 -1          sedan        109.1      188.8      68.9      55.5
# 203 -1          sedan        109.1      188.8      68.9      55.5
# 204 -1          sedan        109.1      188.8      68.9      55.5
#
#      curbweight enginetype  cylindernumber  enginesize  ... citympg  \
# 0    2548        dohc       4               130         ...  21
# ...

# %%
#Applying Label Encoding on remaining categorical columns
varlist=['carbody','enginetype','fuelsystem','Company']
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
carprice[categorical_cols]=carprice[categorical_cols].apply(lambda x: encoder.fit_transform(x))

# %%
carprice.head()
# Out:
#    symboling  fueltype  aspiration  doornumber  carbody  drivewheel  \
# 0  3          1         0           1           0        2
# 1  3          1         0           1           0        2
# 2  1          1         0           1           2        2
# 3  2          1         0           0           3        1
# 4  2          1         0           0           3        0
#
#    enginelocation  wheelbase  carlength  carwidth  ...  fuelsystem  boreratio  \
# 0  0               88.6       168.8      64.1      ...  5           3.47
# 1  0               88.6       168.8      64.1      ...  5           3.47
# 2  0               94.5       171.2      65.5      ...  5           2.68
# 3  0               99.8       176.6      66.2      ...  5           3.19
# 4  0               99.4       176.6      66.4      ...  5           3.19
#
#    stroke  compressionratio  horsepower  peakrpm  citympg  highwaympg  \
# 0  2.68    9.0               111         5000     21       27
# ...

# %%
#Dropping variable with corelation more than 0.8
correlation_matrix = carprice.drop('price', axis=1).corr()
i=0
while i<len(correlation_matrix.columns):
    for j in range(i):
        correlation_matrix = carprice.drop('price', axis=1).corr()
        if abs(correlation_matrix.iloc[i, j]) > 0.8:
            colname = correlation_matrix.columns[i]
            print("Dropped Column: "+colname+" as its corelation with "+ correlation_matrix.columns[j]+" was {:.3f}".format(correlation_matrix.iloc[i, j]))
            carprice.drop(colname,axis=1,inplace=True)
    i=i+1
# Out:
# Dropped Column: carlength as its corelation with wheelbase was 0.875
# Dropped Column: curbweight as its corelation with carwidth was 0.867
# Dropped Column: enginesize as its corelation with cylindernumber was 0.846
# Dropped Column: compressionratio as its corelation with fueltype was -0.984
# Dropped Column: citympg as its corelation with horsepower was -0.801

# %%
plt.figure(figsize=(20,20))
sns.heatmap(abs(carprice.drop('price', axis=1).corr()),annot=True)

# %%
#Splitting the data into X_train and X_test

from sklearn.model_selection import train_test_split
X_train,X_test=train_test_split(carprice, test_size=0.3, random_state=100)

# %%
#Checking the shape of X_train and X_test 

print(X_train.shape)
print(X_test.shape)
# Out:
# (143, 20)
# (62, 20)

# %%
#Dividing X_test into X_test(independent variables) and y(dependent variable price)

y_train=X_train.pop('price')
X_train=X_train

# %%
#Min Max Scaling of numerical columns in X_train

from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()

varlist=['symboling','wheelbase','carwidth','carheight','cylindernumber','boreratio','stroke'
         ,'horsepower','peakrpm','highwaympg']

X_train[varlist]=scaler.fit_transform(X_train[varlist])

# %%
#importing  LinearRegression from SKLearn and creating an object and fitting the model with all variables

from sklearn.linear_model import LinearRegression
lm=LinearRegression()
lm.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#Feature selection using RFE

from sklearn.feature_selection import RFE
rfe=RFE(lm,14)
rfe.fit(X_train, y_train)
# Out:
# RFE(estimator=LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#                                normalize=False),
#     n_features_to_select=14, step=1, verbose=0)

# %%
rfe.support_
# Out:
# array([ True,  True,  True, False,  True,  True,  True,  True,  True,
#         True, False,  True, False, False,  True,  True,  True,  True,
#        False])

# %%
list(zip(X_train.columns,rfe.support_,rfe.ranking_))
# Out:
# [('symboling', True, 1),
#  ('fueltype', True, 1),
#  ('aspiration', True, 1),
#  ('doornumber', False, 3),
#  ('carbody', True, 1),
#  ('drivewheel', True, 1),
#  ('enginelocation', True, 1),
#  ('wheelbase', True, 1),
#  ('carwidth', True, 1),
#  ('carheight', True, 1),
#  ('enginetype', False, 5),
#  ('cylindernumber', True, 1),
#  ('fuelsystem', False, 6),
#  ('boreratio', False, 2),
#  ('stroke', True, 1),
#  ('horsepower', True, 1),
#  ('peakrpm', True, 1),
#  ('highwaympg', True, 1),
#  ('Company', False, 4)]

# %%
X_train_rfe=X_train[X_train.columns[rfe.support_]]
X_train_rfe.head()
# Out:
#      symboling  fueltype  aspiration  carbody  drivewheel  enginelocation  \
# 122  0.6        1         0           3        1           0
# 125  1.0        1         0           2        2           0
# 166  0.6        1         0           2        2           0
# 1    1.0        1         0           0        2           0
# 199  0.2        1         1           4        2           0
#
#      wheelbase  carwidth  carheight  cylindernumber    stroke  horsepower  \
# 122  0.244828   0.291667  0.265487   0.2             0.525253  0.083333
# 125  0.272414   0.666667  0.212389   0.2             0.464646  0.395833
# 166  0.272414   0.308333  0.424779   0.2             0.449495  0.266667
# 1    0.068966   0.316667  0.088496   0.2             0.247475  0.262500
# 199  0.610345   0.575000  0.858407   0.2             0.484848  0.475000
#
#       peakrpm  highwaympg
# 122  0.551020  0.567568
# 125  0.551020  0.270270
# 166  1.000000  0.324324
# 1    0.346939  0.270270
# ...

# %%
#Creating our first model with 15 variables from RFE

X_train_rfe=sm.add_constant(X_train_rfe)
lr1=sm.OLS(y_train,X_train_rfe).fit()
lr1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.840
# Model:                            OLS   Adj. R-squared:                  0.823
# Method:                 Least Squares   F-statistic:                     48.09
# Date:                Tue, 12 May 2020   Prob (F-statistic):           4.91e-44
# Time:                        19:02:51   Log-Likelihood:                -1352.9
# No. Observations:                 143   AIC:                             2736.
# Df Residuals:                     128   BIC:                             2780.
# Df Model:                          14
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
# Check for the VIF values of the feature variables. 
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Calculate the VIFs again for the new model
vif = pd.DataFrame()
vif['Features'] = X_train_rfe.columns
vif['VIF'] = [variance_inflation_factor(X_train_rfe.values, i) for i in range(X_train_rfe.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#           Features     VIF
# 0   const           235.89
# 7   wheelbase       7.94
# 12  horsepower      7.61
# 8   carwidth        6.30
# 14  highwaympg      3.88
# 10  cylindernumber  3.12
# 2   fueltype        2.70
# 9   carheight       2.52
# 1   symboling       2.31
# 5   drivewheel      2.29
# 4   carbody         2.06
# 3   aspiration      1.82
# 13  peakrpm         1.64
# 6   enginelocation  1.25
# 11  stroke          1.21

# %%
#Creating our second model after dropping stroke as it has high P value

X_train_rfe.drop('stroke', axis=1,inplace=True)
lr2=sm.OLS(y_train,X_train_rfe).fit()
lr2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.840
# Model:                            OLS   Adj. R-squared:                  0.824
# Method:                 Least Squares   F-statistic:                     52.19
# Date:                Tue, 12 May 2020   Prob (F-statistic):           6.69e-45
# Time:                        19:02:51   Log-Likelihood:                -1352.9
# No. Observations:                 143   AIC:                             2734.
# Df Residuals:                     129   BIC:                             2775.
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
# Check for the VIF values of the feature variables. 
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Calculate the VIFs again for the new model
vif = pd.DataFrame()
vif['Features'] = X_train_rfe.columns
vif['VIF'] = [variance_inflation_factor(X_train_rfe.values, i) for i in range(X_train_rfe.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#           Features     VIF
# 0   const           221.77
# 7   wheelbase       7.70
# 11  horsepower      7.51
# 8   carwidth        6.30
# 13  highwaympg      3.83
# 10  cylindernumber  3.09
# 2   fueltype        2.62
# 9   carheight       2.49
# 1   symboling       2.31
# 5   drivewheel      2.26
# 4   carbody         2.05
# 3   aspiration      1.82
# 12  peakrpm         1.61
# 6   enginelocation  1.24

# %%
#Creating our third model after dropping peakrpm as it has high P value

X_train_rfe.drop('peakrpm', axis=1,inplace=True)
lr3=sm.OLS(y_train,X_train_rfe).fit()
lr3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.840
# Model:                            OLS   Adj. R-squared:                  0.825
# Method:                 Least Squares   F-statistic:                     56.87
# Date:                Tue, 12 May 2020   Prob (F-statistic):           9.53e-46
# Time:                        19:02:51   Log-Likelihood:                -1353.1
# No. Observations:                 143   AIC:                             2732.
# Df Residuals:                     130   BIC:                             2771.
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
# Check for the VIF values of the feature variables. 
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Calculate the VIFs again for the new model
vif = pd.DataFrame()
vif['Features'] = X_train_rfe.columns
vif['VIF'] = [variance_inflation_factor(X_train_rfe.values, i) for i in range(X_train_rfe.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#           Features     VIF
# 0   const           219.69
# 7   wheelbase       7.63
# 11  horsepower      7.30
# 8   carwidth        6.28
# 12  highwaympg      3.83
# 10  cylindernumber  2.84
# 9   carheight       2.46
# 2   fueltype        2.43
# 1   symboling       2.30
# 5   drivewheel      2.26
# 4   carbody         2.03
# 3   aspiration      1.82
# 6   enginelocation  1.23

# %%
#Creating our fourth model after dropping carheight as it has high P value

X_train_rfe.drop('carheight', axis=1,inplace=True)
lr4=sm.OLS(y_train,X_train_rfe).fit()
lr4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.840
# Model:                            OLS   Adj. R-squared:                  0.826
# Method:                 Least Squares   F-statistic:                     62.35
# Date:                Tue, 12 May 2020   Prob (F-statistic):           1.37e-46
# Time:                        19:02:51   Log-Likelihood:                -1353.2
# No. Observations:                 143   AIC:                             2730.
# Df Residuals:                     131   BIC:                             2766.
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
# Check for the VIF values of the feature variables. 
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Calculate the VIFs again for the new model
vif = pd.DataFrame()
vif['Features'] = X_train_rfe.columns
vif['VIF'] = [variance_inflation_factor(X_train_rfe.values, i) for i in range(X_train_rfe.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#           Features     VIF
# 0   const           208.03
# 10  horsepower      7.11
# 7   wheelbase       6.61
# 8   carwidth        6.24
# 11  highwaympg      3.80
# 9   cylindernumber  2.84
# 2   fueltype        2.40
# 1   symboling       2.28
# 5   drivewheel      2.17
# 4   carbody         1.87
# 3   aspiration      1.81
# 6   enginelocation  1.18

# %%
#Creating our fifth model after dropping symboling as it has high P value

X_train_rfe.drop('symboling', axis=1,inplace=True)
lr5=sm.OLS(y_train,X_train_rfe).fit()
lr5.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.839
# Model:                            OLS   Adj. R-squared:                  0.827
# Method:                 Least Squares   F-statistic:                     68.88
# Date:                Tue, 12 May 2020   Prob (F-statistic):           1.91e-47
# Time:                        19:02:51   Log-Likelihood:                -1353.4
# No. Observations:                 143   AIC:                             2729.
# Df Residuals:                     132   BIC:                             2761.
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
# Check for the VIF values of the feature variables. 
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Calculate the VIFs again for the new model
vif = pd.DataFrame()
vif['Features'] = X_train_rfe.columns
vif['VIF'] = [variance_inflation_factor(X_train_rfe.values, i) for i in range(X_train_rfe.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#           Features     VIF
# 0   const           148.16
# 9   horsepower      7.08
# 7   carwidth        6.16
# 6   wheelbase       5.57
# 10  highwaympg      3.66
# 8   cylindernumber  2.68
# 1   fueltype        2.40
# 4   drivewheel      2.15
# 2   aspiration      1.80
# 3   carbody         1.60
# 5   enginelocation  1.18

# %%
#Creating our sixth model after dropping aspiration as it has high P value

X_train_rfe.drop('aspiration', axis=1,inplace=True)
lr6=sm.OLS(y_train,X_train_rfe).fit()
lr6.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.838
# Model:                            OLS   Adj. R-squared:                  0.828
# Method:                 Least Squares   F-statistic:                     76.70
# Date:                Tue, 12 May 2020   Prob (F-statistic):           2.84e-48
# Time:                        19:02:51   Log-Likelihood:                -1353.7
# No. Observations:                 143   AIC:                             2727.
# Df Residuals:                     133   BIC:                             2757.
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
# Check for the VIF values of the feature variables. 
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Calculate the VIFs again for the new model
vif = pd.DataFrame()
vif['Features'] = X_train_rfe.columns
vif['VIF'] = [variance_inflation_factor(X_train_rfe.values, i) for i in range(X_train_rfe.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#          Features     VIF
# 0  const           120.02
# 8  horsepower      6.09
# 6  carwidth        6.08
# 5  wheelbase       5.54
# 9  highwaympg      3.58
# 7  cylindernumber  2.31
# 3  drivewheel      1.91
# 1  fueltype        1.72
# 2  carbody         1.60
# 4  enginelocation  1.16

# %%
#Creating our seventh model after dropping carbody as it has high P value

X_train_rfe.drop('carbody', axis=1,inplace=True)
lr7=sm.OLS(y_train,X_train_rfe).fit()
lr7.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.837
# Model:                            OLS   Adj. R-squared:                  0.827
# Method:                 Least Squares   F-statistic:                     86.07
# Date:                Tue, 12 May 2020   Prob (F-statistic):           5.15e-49
# Time:                        19:02:51   Log-Likelihood:                -1354.3
# No. Observations:                 143   AIC:                             2727.
# Df Residuals:                     134   BIC:                             2753.
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
# Check for the VIF values of the feature variables. 
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Calculate the VIFs again for the new model
vif = pd.DataFrame()
vif['Features'] = X_train_rfe.columns
vif['VIF'] = [variance_inflation_factor(X_train_rfe.values, i) for i in range(X_train_rfe.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#          Features     VIF
# 0  const           107.86
# 7  horsepower      6.05
# 5  carwidth        5.79
# 4  wheelbase       4.05
# 8  highwaympg      3.55
# 6  cylindernumber  2.31
# 1  fueltype        1.72
# 2  drivewheel      1.65
# 3  enginelocation  1.16

# %%
#Creating our eighth model after dropping wheelbase as it has high P value

X_train_rfe.drop('wheelbase', axis=1,inplace=True)
lr8=sm.OLS(y_train,X_train_rfe).fit()
lr8.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.835
# Model:                            OLS   Adj. R-squared:                  0.827
# Method:                 Least Squares   F-statistic:                     97.78
# Date:                Tue, 12 May 2020   Prob (F-statistic):           1.05e-49
# Time:                        19:02:51   Log-Likelihood:                -1355.1
# No. Observations:                 143   AIC:                             2726.
# Df Residuals:                     135   BIC:                             2750.
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
# Check for the VIF values of the feature variables. 
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Calculate the VIFs again for the new model
vif = pd.DataFrame()
vif['Features'] = X_train_rfe.columns
vif['VIF'] = [variance_inflation_factor(X_train_rfe.values, i) for i in range(X_train_rfe.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#          Features     VIF
# 0  const           102.07
# 6  horsepower      4.92
# 4  carwidth        3.52
# 7  highwaympg      3.15
# 5  cylindernumber  2.25
# 1  fueltype        1.66
# 2  drivewheel      1.51
# 3  enginelocation  1.16

# %%
X_train_rfe.columns
# Out:
# Index(['const', 'fueltype', 'drivewheel', 'enginelocation', 'carwidth',
#        'cylindernumber', 'horsepower', 'highwaympg'],
#       dtype='object')

# %%
y_train_predict=lr8.predict(X_train_rfe)

# %%
#Residual analysis
sns.distplot(y_train-y_train_predict)

# %%
sns.scatterplot(y_train,y_train-y_train_predict)

# %%
X_test
# Out:
#      symboling  fueltype  aspiration  doornumber  carbody  drivewheel  \
# 160  0          1         0           0           3        1
# 186  2          1         0           0           3        1
# 59   1          1         0           1           2        1
# 165  1          1         0           1           3        2
# 140  2          1         0           1           2        0
# ..  ..         ..        ..          ..          ..       ..
# 28  -1          1         0           0           4        1
# 29   3          1         1           1           2        1
# 182  2          0         0           1           3        1
# 40   0          1         0           0           3        1
# 128  3          1         0           1           0        2
#
#      enginelocation  wheelbase  carwidth  carheight  enginetype  \
# 160  0               95.7       64.4      53.0       3
# 186  0               97.3       65.5      55.7       3
# ...

# %%
#Min Max Scaling of numerical columns in X_test
varlist=['symboling','wheelbase','carwidth','carheight','cylindernumber','boreratio','stroke'
         ,'horsepower','peakrpm','highwaympg']

X_test[varlist]=scaler.transform(X_test[varlist])

# %%
#Transforming X_test for model prediction and creating y_test

varlist=['fueltype', 'drivewheel', 'enginelocation', 'carwidth','cylindernumber', 'horsepower', 'highwaympg']
y_test=X_test.pop('price')
X_test=X_test[varlist]

# %%
X_test=sm.add_constant(X_test)
y_test_predict=lr8.predict(X_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_test_predict)
# Out:
# 0.8443878017737757

# %%
sns.scatterplot(y_test,y_test_predict)

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test,y_test_predict)
# Out:
# 10897381.638469841

# %%
sns.distplot(y_test-y_test_predict)

# %%
#y_test=X_test.pop('price')
X_test=X_test[['fueltype','horsepower']]

sm.add_constant(X_test)
# Out:
#      const  fueltype  horsepower
# 160  1.0    1         0.091667
# 186  1.0    1         0.154167
# 59   1.0    1         0.150000
# 165  1.0    1         0.266667
# 140  1.0    1         0.104167
# ..   ...   ..              ...
# 28   1.0    1         0.166667
# 29   1.0    1         0.404167
# 182  1.0    0         0.016667
# 40   1.0    1         0.158333
# 128  1.0    1         0.662500
#
# [62 rows x 3 columns]

# %%
y_test_predict=lr17.predict(X_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_test_predict)

# %%
# Out:
# 0.6869460300456645
